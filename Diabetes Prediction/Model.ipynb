# %%
import pandas as pd
import numpy as np

data=pd.read_csv("/content/Dataset.csv",header=0)
data
df=pd.DataFrame(data)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isnull().sum()
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
x=df.drop(columns=df.columns[8], axis=1)
x
y=df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
df['Outcome']=lb.fit_transform(df['Outcome'])
df['Outcome']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
predict = model.predict(X_test)
predict

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predict)
print(f'Accuracy: {accuracy:.2f}')

import pickle
filename = 'diabetes_model.pkl'
# save the model
with open(filename, 'wb') as file:
    pickle.dump(model, file)

print("Model Saved Successfully")
# Out:
# Accuracy: 0.79
# Model Saved Successfully

# %%
|# import pickle
# filename = 'diabetes_model.pkl'
# # save the model
# with open(filename, 'wb') as file:
#     pickle.dump(model, file)

# print("Model Saved Successfully")

# %%
# data=input()
# data=tuple(float(item) for item in data.split(','))
# data=np.array(data)
# data=data.reshape(1,-1)
# predict=model.predict(data)
# if predict[0]==1:
#   print("PATIENT HAS DIABETESE")
# else:
#   print("PATIENT DOES NOT HAS DIABITIC")



print("Enter patient details for diabetes prediction")
pregnancies = float(input("Number of Pregnancies: "))
glucose = float(input("Glucose Level: "))
blood_pressure = float(input("Blood Pressure: "))
skin_thickness = float(input("Skin Thickness: "))
insulin = float(input("Insulin Level: "))
bmi = float(input("BMI: "))
dpf = float(input("Diabetes Pedigree Function: "))
age = float(input("Age: "))

user_data = np.array([pregnancies, glucose, blood_pressure, skin_thickness, insulin, bmi, dpf, age]).reshape(1, -1)

# Scale user_data using the same scaler used for training
user_data = sc.transform(user_data)
# Predict diabetes1

prediction = model.predict(user_data)
if prediction[0]==1:
  print("PATIANT HAS DIABETES ")
else:
  print("PATIANT DOES NOT HAVE DIABETES")
# Out:
# Enter patient details for diabetes prediction
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c6db7c450500> in <cell line: 0>()
#      12
#      13 print("Enter patient details for diabetes prediction")
# ---> 14 pregnancies = float(input("Number of Pregnancies: "))
#      15 glucose = float(input("Glucose Level: "))
#      16 blood_pressure = float(input("Blood Pressure: "))
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...
