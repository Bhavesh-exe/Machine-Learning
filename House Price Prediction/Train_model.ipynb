# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/House_dataset.csv')
data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
data['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
x=data.drop(['medv'],axis=1)
y=data['medv']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
predict = model.predict(x_test)
print(predict)
# Out:
# [22.8142152  18.07093559 31.48605726 38.34549729 12.10070709 24.08748199
#  34.54973441 32.63605261 21.93594803  6.87350956 24.64250536 25.95169057
#  15.06961097 23.67107016 16.96586447 23.04034707 12.36235228 18.60801273
#  38.04932606 18.1724404  25.85851409 31.14279469 16.14840196 30.14516145
#  15.55336252 14.45817131 28.55889861 19.30001822 26.52785969 17.94091506
#  28.63186679 17.57559119 16.47874092 12.15248199 37.04148883 17.66795014
#   8.99313632 19.711175   27.92026086 19.05231266 33.12768493 27.06261773
#  19.76195206 23.85546351 24.2556638  18.71204082 10.37621768 15.75945522
#  18.28611889 41.50046751 19.83784104 11.39466541 28.41983466 33.36294635
#  18.20953833 36.47253356 31.12477532 15.27401511 17.38262266  7.16322452
#  24.82449211 12.89474369 35.55544847 25.64019601 29.7369633  12.23157877
#   4.57898866 15.3664335  18.84715024 12.39620358 24.59014206 15.05049124
#  20.27860695 20.10392179  8.30259429 16.47683287 27.84102429 24.64378061
#  20.39106348 22.76191979 20.13725324 18.69421437 18.9055807  35.54985339
#  24.90500716 24.82987749 16.41797725 33.52196002 20.4843069  30.62441542
#  17.56972166  0.46458614 19.60292764 24.97449409 41.44868926 30.26540315
#  22.03522819 20.88269502 21.22439782  5.795119   24.71708682 23.22619376]

# %%
from sklearn.metrics import r2_score
print("Accuracy: ",r2_score(y_test,predict))

import pickle

filename = 'model.pkl'
# save the model
with open(filename, 'wb') as file:
    pickle.dump(model, file)

print("Model Saved Successfully")
# Out:
# Accuracy:  0.5869979037232673
# Model Saved Successfully
